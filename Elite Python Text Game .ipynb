# %%
# Docstring explaining the premise of the game
""""
DocString:

Introduction: This game is based on the Netflix series called Elite. 
This TV series is about a hard working boy named Samuel that gets enrolled 
into one of the most exclusive schools in Spain. There he finds to learn that 
everything is not always what they seem to be. This leads to him clashing with
the wealthy kids involving a murderd investigation. The game is only based off
of season one of Elite. I have created 3 stages where the player will discover
who is the killer.

Here is my source about the Netflix series Elite. 
https://www.imdb.com/title/tt7134908/

Here are the events listed in order:
> Start 
>Stage 1
>Stage 2
>Stage 3 
>End 

"""
#import random package to use random.choice for creating replay value 
import random 

#Benginng of the game, stage 1 
def stage_0():

#Defining question variable 
    question = input(prompt = "Are you ready to play?\n").lower()

#Start of conditional statement
    if question == ('yes'):
        print("great lets begin the game\n")
        classroom_318()

    elif question == ('no'):
        print("Too bad, lets begin the game") 
        classroom_318()

    else:
        print("Please try again\n")
        fail()

# Defining the first stage of the game

def classroom_318():
    
#Printing the brief and question 
    print(f"""
Welcome to Spain! We hope you enjoy your new school called Las Encinas.
You're in classroom 318. You and Samuel just became good friends. He ask you
if you want to join him at a party tonight. Should you go to the party? 
\n""")
    
    print(f"""
After deciding whether to go or not. You join Sammuel at the party. 
He introduces you to Polo, Nano, Carla, Guzman, and Marina. Samuel tells you
that Marina is his girlfriend but you notice something is off that night. You
see that Nano the brother of Samuel is kissing Marina.\n""")


# Defining action input variable 
    action = input(prompt= "Decide whether or not to tell Samuel").lower()

# Starting Conditional statement for stage 1  
    if action == 'yes':
        print(f"""
Samuel is upset and will confront his brother at the dance.""")
        school_dance()
        
    elif action == 'no':
        print(f""" 
You keep it to yourself and go to the school dance with Samuel.""")
        school_dance()
            
    else:
        print("Please try again\n")
        stage_0()
        
# Defining Second Stage 

def school_dance():
#Printing brief for Stage 2 
    print(f"""
You just arrived at the school dance
You and Samuel are now dancing. 45 minutes pass by and you notice everyone 
is gone, including Samuel. You walk towards the bathroom near the locker 
rooms. You see a shadow near the door and open it. There you find Samuel 
holding on to Marina’s dead body. Police arrived 20 minutes later. The 
police take you in for questioning. 

""")


    print("""You're inside the police car.""")
  
 # make any choice input to have an interaction with the player by giving them three choice

    choice_3 = input(prompt = """You have to tell us what happen or you will be suspects for murder. 
Press any key to see your answer""")
    
# Instantiating random variable    
    answer = random.randint(1,3)

# starting nested conditional for stage 2     
    if answer == 1 :
        print('Yes, I will speak')
        police_station()
        
    elif answer == 2 :
        print('No, I will not speak')
        police_station()
        
    elif answer == 3 :
        print('I will keep quiet')
        stage_0()
        
    else:
        print('Try again')
        fail()



#  Defining Third Stage
          
""""
You just arrived to the police station for questioning.
"""
def police_station():
    
# Printing brief for stage 3 and requesting input from user to proceed 
    print("You're in the police station\n")
    input(prompt = '<Press any key to continue>\n')
    
    print("Press 1 to go into the interrogation_room.")
    print("Press 2 to fail.") 

# Defing choice 2 variable and starting conditional statement 
    choice_2 = input(prompt = ">")
    
    if choice_2 == '1':
        print(f"""You go to answer choice_3. 
We have three suspects. Nano tells investigators that he was looking for 
Marina, so they can run away and be together. Polo tells investigators he was 
using the restroom and left early due to drinking too much. However
investigators found blood on his shoes. Carla tells 
investigators she was using the restroom. Samuel tells investigators he was 
looking for his friends. Who killed Marina on Friday night?
1) Samuel  
2) Polo 
3) Nano
4) Carla \n""")
        
# Defining choice 3 variable 
        choice_3 = input(">") 

# Start of nested conditional
        if choice_3 == '1':
            print("That's incorrect.")
            fail()
           
        elif choice_3 =='2':
            print("That's correct! You won!")

            
        elif choice_3 == '3':
            print("That's incorrect.")
            fail()
            
        elif choice_3 == '4':
            print("That's incorrect.")
            fail()
        else:
            print("Invalid entry. Please try again.\n")
            input(prompt = '<Press any key to End the Game>\n')
            fail() 
        
    
    elif choice_2 == '2':
        print("try again")
        police_station()
    
    else:
        print("Invaid")
        fail()
            
# Defining fail function 
def fail():
        print("You've failed")
        input(prompt = '<Press any key to exit>\n')
    
stage_0()
